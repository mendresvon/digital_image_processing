# %%
from google.colab.patches import cv2_imshow #要在Colab使用cv2顯示影像，一定要先宣告這行

# %%
import cv2
import numpy as np

height = 160                    # 影像高
width = 280                     # 影像寬
# 建立BGR影像陣列
image = np.zeros((height, width, 3), np.uint8)
#image[:,:,0] = 255              # 建立 B 通道像素值
cv2_imshow(image)      # 顯示影像

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=280x160>

# %%
import cv2
import numpy as np

height = 160                                # 影像高
width = 280                                 # 影像寬
# 建立BGR影像陣列
image = np.zeros((height, width, 3), np.uint8)
blue_image = image.copy()
blue_image[:,:,0] = 255                     # 建立 B 通道像素值
cv2_imshow(blue_image)        # 顯示blue image影像

green_image = image.copy()
green_image[:,:,1] = 255                    # 建立 G 通道像素值
cv2_imshow(green_image)      # 顯示green image影像

red_image = image.copy()
red_image[:,:,2] = 255                      # 建立 R 通道像素值
cv2_imshow(red_image)          # 顯示red image影像

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=280x160>
# <PIL.Image.Image image mode=RGB size=280x160>
# <PIL.Image.Image image mode=RGB size=280x160>

# %%
import cv2
import numpy as np

height = 160                # 影像高
width = 280                 # 影像寬
# 使用random.randint()建立GRAY影像陣列
image = np.random.randint(256,size=[height,width,3],dtype=np.uint8)
cv2_imshow(image)  # 顯示影像

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=280x160>

# %%
import cv2
import numpy as np

height = 150                # 影像高
width = 300                 # 影像寬
image = np.zeros((height,width,3),np.uint8)
image[0:50,:,0] = 255       # blue
image[50:100,:,1] = 255     # green
image[100:150,:,2] = 255    # red
cv2_imshow(image)  # 顯示影像

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=300x150>

# %%
# Out:
# <PIL.Image.Image image mode=L size=280x160>

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=300x150>
